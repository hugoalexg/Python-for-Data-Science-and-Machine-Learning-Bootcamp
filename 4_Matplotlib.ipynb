# %% [markdown]
# <a href="https://colab.research.google.com/github/hugoalexg/Python-for-Data-Science-and-Machine-Learning-Bootcamp/blob/main/4_Matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Exercises
# Follow the instructions to recreate the plots using this data:

# %%
import matplotlib.pyplot as plt
import numpy as np
from random import sample
 
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# Exercise 1 - Follow along with these steps:
# * ** Create a figure object called fig using plt.figure() **
# * ** Use add_axes to add an axis to the figure canvas at [0,0,1,1]. Call this new axis ax. **
# * ** Plot (x,y) on that axes and set the labels and titles to match the plot below:**

# %%
fig = plt.figure()
ax = fig.add_axes([0.1, 0.1, 0.9, 0.9])
ax.plot(x, y, 'b')
ax.set_xlabel('x') 
ax.set_ylabel('y')
ax.set_title('title')
plt.tight_layout()
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:7: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   import sys

# %% [markdown]
# Exercise 2
# ** Create a figure object and put two axes on it, ax1 and ax2. Located at [0,0,1,1] and [0.2,0.5,.2,.2] respectively.**

# %%
fig = plt.figure()
ax1 = fig.add_axes([0.1, 0.1, 0.9, 0.9])
ax2 = fig.add_axes([0.2, 0.5, 0.2, 0.2]) 
ax1.plot(x, y, 'r')
ax1.set_xlabel('x') 
ax1.set_ylabel('y')
ax2.plot(x, y, 'r')
ax2.set_xlabel('x') 
ax2.set_ylabel('y')
plt.tight_layout()
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:10: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   # Remove the CWD from sys.path while we load stuff.

# %% [markdown]
# Exercise 3
# ** Create the plot below by adding two axes to a figure object at [0,0,1,1] and [0.2,0.5,.4,.4]**

# %%
fig = plt.figure()
ax1 = fig.add_axes([0.1, 0.1, 0.9, 0.9])
ax2 = fig.add_axes([0.2, 0.5, 0.4, 0.4]) 
ax1.plot(x, z, 'b')
ax1.set_xlabel('x') 
ax1.set_ylabel('z')
ax2.plot(x, y, 'b')
ax2.set_xlabel('x') 
ax2.set_ylabel('y')
ax2.set_title('zoom')
ax2.set_ylim([30, 50])
ax2.set_xlim([20, 22])
plt.tight_layout()
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:13: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   del sys.path[0]

# %% [markdown]
# Exercise 4
# ** Use plt.subplots(nrows=1, ncols=2) to create the plot below.**

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(12,6))
axes[0].plot(x, y, color="blue", lw=3, ls='--')
axes[1].plot(x, z, color="red", lw=3 )
plt.tight_layout()
plt.show()

# %% [markdown]
# BONUS: #-------------gerando curva normal-----------------

# %%
n = np.random.randn(100000)
n = n
i = np.linspace(-3,3,61)
res = np.zeros(61)
 
for var in range(len(n)):
    for j in range(len(i)-1):
        if n[var] > i[j] and n[var] <= i[j + 1]:
            res[j] = res[j] + 1

# %%
fig = plt.figure()
ax = fig.add_axes([0.1, 0.1, 0.9, 0.9])
ax.plot(i, res, 'b')
plt.tight_layout()
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   after removing the cwd from sys.path.
